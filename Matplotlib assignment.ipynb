# %%
# Answer 1:-

# %%
# Matplotlib is a powerful plotting library in Python used for creating static, animated, and interactive visualizations. 
#  It is used for visualising data.five plots that can be used by matplotlib are : Line Graph,Bar chart,Histograms,Scatter Plot,Pie Chart

# %%
# Answer 2:-

# %%
# The matplotlib.pyplot.scatter() plots serve as a visual tool to explore and analyze the relationships between variables, utilizing dots to depict the connection between them.

# %%
import matplotlib.pyplot as plt

# %%
import numpy as np

# %%
np.random.seed(3)

# %%
x = 3+np.random.normal(0,2,50)
y = 3+np.random.normal(0,2,len(x))
plt.xlabel('x axis')
plt.ylabel('y axis')
plt.title('My plot')
plt.scatter(x,y)

# %%
# Answer 3:-

# %%
# subplot() function adds subplot to a current figure at the specified grid position.

# %%
x = np.array([0,1,2,3,4,5]) and y = np.array([0,100,200,300,400,500])
x = np.array([0,1,2,3,4,5]) and y = np.array([50,20,40,20,60,70])
x = np.array([0,1,2,3,4,5]) and y = np.array([10,20,30,40,50,60])
x = np.array([0,1,2,3,4,5]) and y = np.array([200,350,250,550,450,150])
# Out:
#   Cell In[11], line 1
#     x = np.array([0,1,2,3,4,5]) and y = np.array([0,100,200,300,400,500])
#     ^
# SyntaxError: invalid syntax. Maybe you meant '==' or ':=' instead of '='?

# %%
# A bar graph, also known as a bar chart, is a graphical display of data using bars of different heights or lengths. It is used to compare quantities across
# different categories. Each bar represents a category of data, and the size of the bar represents the value or frequency of the category it corresponds to.

# %%
x = np.array(['Apple','Microsoft','Google','AMD'])
y = np.array([3000,8000,1000,10000])

# %%
plt.xlabel('company_name')
plt.ylabel('profit')
plt.bar(company_name,profit)
# Out:
# <BarContainer object of 4 artists>

# %%
# Answer 5:-

# %%
# Box plot is a graphical representation of the distribution of a dataset.
#  By using Box plot you can provide a summary of the distribution, identify potential and compare different datasets in a compact and visual manner.

# %%
box1 = np.random.normal(100,10,200)
box2 = np.random.normal(90,20,200)

# %%
box2-box1
# Out:
# array([-39.90993483, -19.21813771, -42.98709843,  -8.16981793,
#          5.65663229, -21.83791489,  15.88325469, -14.35510143,
#         -4.10293003,   0.45805328,  -7.07073563,  20.57018642,
#          7.71373377, -31.05355199,  -5.91936864, -22.93462367,
#         -4.61893035,   3.86601598,  17.27027305, -32.67401871,
#         -5.04944162,  16.18411197, -28.70292268,  11.89052782,
#         13.39868942,  -1.56850417, -47.36271401, -10.18569113,
#        -33.53033204, -10.17141885,  -5.00848606, -37.34556307,
#        -39.11523726, -28.92696114,  -4.22993928,   0.58855562,
#         -6.09262754, -17.83429635, -37.78009359,   0.14008768,
#        -18.5710987 ,  30.58923707,  -3.60773584, -53.95760909,
#        -36.24352798,  19.44708639, -50.77045866, -17.16878657,
#          8.5805937 , -16.32646138,  21.61349269,  34.0242488 ,
#         -7.66054517,   5.95403542, -29.67713858, -25.73107091,
#          3.81259156,  10.56808064, -12.72351206, -11.63860572,
# ...
